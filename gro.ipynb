# %%
pip install -U langchain langchain-groq
# Out:
# ...
#   Using cached langchain_groq-1.1.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.8 MB/s  0:00:00
# ...
# Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Using cached langchain_groq-1.1.1-py3-none-any.whl (19 kB)
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key="use groq api",
    model_name="openai/gpt-oss-120b"
)

response = llm.invoke("who is god of cricket")
print(response)
# Out:
# content='The title **“God of Cricket”** is most commonly associated with **Sachin\u202fTendulkar**.  \n\n- **Why Sachin?**  \n  - He debuted for India at just 16 and enjoyed a 24‑year international career (1990‑2013).  \n  - He holds the record for the most runs in both Test (15,921) and One‑Day International (18,426) cricket.  \n  - He was the first player to score a double‑century in ODIs and the first to reach 100 international centuries.  \n  - His calm demeanor, technical mastery, and ability to perform under pressure earned him reverence from fans worldwide, leading many to call him the “God of Cricket.”  \n\n- **Other legends sometimes mentioned**  \n  - **Sir Don Bradman** – often dubbed the “God of Cricket” for his unparalleled Test average of 99.94.  \n  - **Virat Kohli**, **Ricky Ponting**, **Brian Lara**, etc., are also celebrated, but the specific epithet “God of Cricket” is most strongly linked to Sachin Tendulkar.  \n\nSo, when people refer to the “God of Cricket,” the
# ...
